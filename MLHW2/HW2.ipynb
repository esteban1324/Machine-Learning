# %% [markdown]
# HW2 Question 2 Testing Plots for SVM Model

# %%
import numpy as np
import matplotlib.pyplot as plt
import sklearn.svm as svm

# %%
def plot_data(X):
    x_coord_class1 = [points[0] for points in X[:3]]    
    y_coord_class1 = [points[1] for points in X[:3]]
    x_coord_class2 = [points[0] for points in X[3:]]
    y_coord_class2 = [points[1] for points in X[3:]]
    
    plt.xlabel('x')
    plt.ylabel('y')
    
    plt.scatter(x_coord_class1, y_coord_class1, color='blue', label='Class 1')
    plt.scatter(x_coord_class2, y_coord_class2, color='red', label='Class 2')
    plt.legend(loc = 'upper right') 
    
    plt.show()

# %%
X = [(1,1), (1,2), (2,1), (0,0), (1,0), (0,1)]
plot_data(X)

# %% [markdown]
# SVM Training and plotting

# %%
# class labels for the data
X_train = np.array(X)
y = [1, 1, 1, -1, -1, -1]

classifier = svm.SVC(kernel='linear', C=10.0)
classifier.fit(X_train, y)
# Out:
# SVC(C=10.0, kernel='linear')

# %%
# plot the decision boundary and get the weights of the model for the SVM from our data

weights = classifier.coef_[0]

y_intercept = classifier.intercept_

# plot a line that separates the two classes using the weights and the y-intercept
x = np.linspace(0, 3, 10)

# formula for weights and y-int for decision boundary 
w = - (weights[0] / weights[1])
b = - (y_intercept[0] / weights[1])
y = w * x + b

# plot the decision boundary line
plt.plot(x, y, 'g', label='decision boundary')
plt.xlabel('x')
plt.ylabel('y')
plot_data(X)
plt.show()
